# %% [markdown]
# # Customer Lifetime Value (CLV) Prediction
#
# Predictive follow-up to the historical **average revenue per customer** analysis in `04_EDA/nordhome_eda.ipynb`.
#
# That analysis answered *"what have customers spent so far?"* — a backward-looking average with no time dimension.
# This notebook asks the forward-looking question: *"what is a customer likely to be worth over their remaining lifetime?"*
#
# **Planned approach:** heuristic CLV
# ```
# CLV = Average Order Value x Purchase Frequency x Customer Lifespan
# ```
#
# **Data coverage:** 2021 – mid 2024 (H1)
# **Schema:** `mart`
# **Data quality:** Unknown/ghost customers are excluded using existing quality flags (`is_unknown_customer`), consistent with `04_EDA`.

# %% [markdown]
# ## Setup

# %%
import sys
sys.path.append("../04_EDA")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns
from sqlalchemy import create_engine
from matplotlib.ticker import FuncFormatter

# Update password before running
engine = create_engine("postgresql+psycopg2://postgres:eileensf@localhost:5432/nordhome_retail")

# Reuse the shared EDA style tokens/helpers instead of duplicating them
from base_style import (ACCENT, GREY_LABEL, GREY_TEXT, BLUES)

# %% [markdown]
# ---
# ## 1. Define the grain and inputs
#
# > **Question:** Which age group / loyalty segment has the highest predicted customer lifetime value?
#
# Before writing SQL, clarify:
# - **Grain:** one row per customer
# - **AOV:** revenue / orders, computed per customer (or per segment)
# - **Purchase frequency:** orders per active year
# - **Customer lifespan:** estimated average active duration — needs a documented assumption, since currently-active customers have a censored (unknown) lifespan
#
# *(Analysis to be added in a later session.)*
